# %%
import pickle

name = 'answers_model_likes'
with open('./' + name + '.pkl', 'rb') as f:
    answers_model_likes = pickle.load(f)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
sns.set_context("poster")

plt.hist(answers_model_likes['where_good'], color='r',bins=10,range=(0,10), normed=True)
plt.xticks(np.arange(1,11)-0.5,np.arange(1,11))
plt.xlabel('Answer Number')

plt.tight_layout()
plt.show()

# %%
x = np.array(answers_model_likes['where_good'])[np.where(answers_model_likes['skip_bool'])[0]]

plt.hist(x, color='r',bins=10,range=(0,10), normed=True)
plt.xticks(np.arange(1,11)-0.5,np.arange(1,11))
plt.xlabel('Answer Number')

plt.tight_layout()
plt.show()

# %%
answers_model_likes.keys()
# Out:
# dict_keys(['multi', 'where_good', 'skip_bool', 'no_good', 'total', 'skip_first', 'good'])

# %%
answers_model_likes['multi']/answers_model_likes['total'] #how often more than one answer selected
# Out:
# 0.03939393939393939

# %%
answers_model_likes['good']/answers_model_likes['total'] #how an item selected...not very often
# Out:
# 0.22424242424242424

# %%
answers_model_likes['multi']/answers_model_likes['good'] #no more often to have more than one given one (it doesn't like topics/questions)
# Out:
# 0.17567567567567569

# %%
answers_model_likes['skip_first']/answers_model_likes['total'] #how often not first selected
# Out:
# 0.0797979797979798

# %%
answers_model_likes['skip_first']/answers_model_likes['good'] #how often not first selected given that one selected
# Out:
# 0.35585585585585583

# %% [markdown]
# a more qualitative study would also be good...just click around and see what the model seems to like
